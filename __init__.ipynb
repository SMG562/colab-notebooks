# %% [markdown]
# # Example 1
#
# Subclass has new properties.
#
#
#
# ```
# # This is formatted as code
# ```

# %%
class A(object):
    def __init__(self, name):
        print("A init called")
        self.name = name
 
 
class B(A):
    def __init__(self, age, name):
        # Calling init of parent class
        A.__init__(self, name)
        print("B init called")
        self.age = age

# %%
obj = B(10,"John")
# Out:
# A init called
# B init called

# %%
obj.name
# Out:
# 'John'

# %%
obj.age
# Out:
# 10

# %% [markdown]
# # Example 2:
# subclass has only new methods.

# %%
class A:
    def __init__(self, n='Rahul'):
        self.name = n
 
 
class B(A):
    def __init__(self, age):
        self.age = age
 
 
object = B(23)
print(object.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-da9c2cc1c333> in <module>
#      10
#      11 object = B(23)
# ---> 12 print(object.name)
#
# AttributeError: 'B' object has no attribute 'name'

# %% [markdown]
# Correct:

# %%
class A:
    def __init__(self, n='Rahul'):
        self.name = n
 
 
class B(A):
    def __init__(self, age):
        self.age = age
        A.__init__(self)
 
 
object = B(23)
print(object.name)
# Out:
# Rahul

# %%
# Python code to demonstrate how parent constructors
# are called.

# parent class
class Person(object):

	# __init__ is known as the constructor
	def __init__(self, name, idnumber):
		self.name = name
		self.idnumber = idnumber

	def display(self):
		print(self.name)
		print(self.idnumber)

# child class


class Employee(Person):
	def __init__(self, name, idnumber, salary, post):
		self.salary = salary
		self.post = post

		# invoking the __init__ of the parent class
		Person.__init__(self, name, idnumber)


# creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using its instance
a.display()

# %%
Example 4 
Multiple inheritage

# %%
# Python example to show the working of multiple
# inheritance

class Dad():
  def __init__(self):
    self.gen1 = "tall"
    self.name = "Bob"
    print("Dad")

class Mom():
  def __init__(self):
    self.gen2 = "white"
    self.name = "Kate"
    print("Mom")

class Kids(Dad, Mom):
  def __init__(self):
    Dad.__init__(self)
    Mom.__init__(self)
    print("here is the kids")
    
  def printGens(self):
    print(self.gen1, self.gen2)

# %%
ob = Kids()
ob.printGens()
# Out:
# Dad
# Mom
# here is the kids
# tall white

# %% [markdown]
# ref:
# [Inheritance in Python - GeeksforGeeks](https://www.geeksforgeeks.org/inheritance-in-python/)
