# %% [markdown]
# ref:
#
# [Enumerate() in Python - GeeksforGeeks](https://www.geeksforgeeks.org/enumerate-in-python/)

# %% [markdown]
# Often, when dealing with iterators, we also get need to keep a count of iterations. Python eases the programmers’ task by providing a built-in function enumerate() for this task.
#
# Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object.
#
# This enumerated object can then be used directly for loops or converted into a list of tuples using the list() method.
#
#
# Syntax:
#
# ```
# enumerate(iterable, start=0)
# ```
#
# Parameters:
#
# - Iterable: any object that supports iteration
# - Start: the index value from which the counter is to be started, by default it is 0

# %%
daily_routine = ["eat", "sleep", "repeat"]

# %%
obj1 = enumerate(daily_routine)

# %%
print ("Return type:", type(obj1))
# Out:
# Return type: <class 'enumerate'>

# %%
list(obj1)
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %%
for ele in list(obj1):
    print (ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')

# %%
for ele in obj1:
    print (ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')

# %%
for count, ele in enumerate(daily_routine, 100):
    print (count, ele)
# Out:
# 100 eat
# 101 sleep
# 102 repeat

# %%
for count, ele in enumerate(l1):
    print(count)
    print(ele)
